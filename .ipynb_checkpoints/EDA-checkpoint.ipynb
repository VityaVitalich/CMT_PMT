# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

from tqdm import tqdm
from sklearn.linear_model import ElasticNet
import statsmodels.api as sm

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('Cleaned_data.xlsx')
df = df.drop(columns=['log'])
df['gender'] = pd.factorize(df['gender'])[0]


df.columns = ['age', 'gender', 'ACC_ADD1', 'ACC_ADD2', 'ACC_ADD3', 'ACC_DIV1', 'ACC_DIV2', 'ACC_DIV3', 'ACC_MUL1',
       'ACC_MUL2', 'ACC_MUL3', 'ACC_SUB1', 'ACC_SUB2', 'ACC_SUB3', 'RT_ADD1', 'RT_ADD2', 'RT_ADD3',
       'RT_DIV1', 'RT_DIV2', 'RT_DIV3', 'RT_MUL1', 'RT_MUL2', 'RT_MUL3',
       'RT_SUB1', 'RT_SUB2', 'RT_SUB3', 'ADD1', 'ADD2', 'ADD3', 'DIV1',
       'DIV2', 'DIV3', 'MUL1', 'MUL2', 'MUL3', 'SUB1', 'SUB2',
       'SUB3', 'm_score_bal', 'acc_1_bal', 'acc_2_bal', 'acc_3_bal',
       'acc_4_bal', 'acc_5_bal', 'acc_6_bal', 'rt_1_bal', 'rt_2_bal',
       'rt_3_bal', 'rt_4_bal', 'rt_5_bal', 'rt_6_bal', 'm_score_cl',
       'acc_1_cl', 'acc_2_cl', 'acc_3_cl', 'acc_4_cl', 'acc_5_cl', 'acc_6_cl',
       'rt_1_cl', 'rt_2_cl', 'rt_3_cl', 'rt_4_cl', 'rt_5_cl', 'rt_6_cl',
       'n_sum', 'rt_mean', 'rt_cmt_mean', 'rt_bal', 'rt_cl']

# %%
def create_y(df):
    var_names = []
    for i in range(26, 38):
        name = df.iloc[:,i].name
        vals = df.iloc[:,i]

        var_names.append(name)

        globals()[name] = vals

    for i in range(2, 14):
        name = df.iloc[:,i].name
        vals = df.iloc[:,i]

        var_names.append(name)

        globals()[name] = vals


    global ADD 
    global DIV
    global SUB
    global MUL

    global SUM
    
    ADD = ADD1 + ADD2 + ADD3
    DIV = DIV1 + DIV2 + DIV3
    SUB = SUB1 + SUB2 + SUB3
    MUL = MUL1 + MUL2 + MUL3
    
    SUM = ADD + DIV + SUB + MUL

    var_names += ['ADD', 'DIV', "MUL", 'SUB', "SUM"]
    
    return var_names

# %%
var_names = create_y(df)

# %%
ADD
# Out:
# 0      50
# 1      72
# 2      68
# 3      40
# 4      76
#        ..
# 215    58
# 216    61
# 217    40
# 218    56
# 219    49
# Length: 220, dtype: int64

# %%
var_names
# Out:
# ['ADD1',
#  'ADD2',
#  'ADD3',
#  'DIV1',
#  'DIV2',
#  'DIV3',
#  'MUL1',
#  'MUL2',
#  'MUL3',
#  'SUB1',
#  'SUB2',
#  'SUB3',
#  'ACC_ADD1',
#  'ACC_ADD2',
#  'ACC_ADD3',
#  'ACC_DIV1',
#  'ACC_DIV2',
#  'ACC_DIV3',
#  'ACC_MUL1',
#  'ACC_MUL2',
#  'ACC_MUL3',
#  'ACC_SUB1',
#  'ACC_SUB2',
#  'ACC_SUB3',
#  'ADD',
#  'DIV',
#  'MUL',
#  'SUB',
#  'SUM']

# %%
def make_X(df, y_name):
    
    if y_name != 'SUM':
    
        number_level = None

        difficulties = ['ADD', 'SUB', 'MUL', 'DIV']

        columns_to_drop = ['n_sum']


        try: 
            number_level = int(y_name[-1])
        except ValueError:
            y_name = y_name + '1'
            number_level = 1

        if 'ACC' in y_name:
            base_name = y_name[4:-1]
        else:
            base_name = y_name[:-1]

        columns_to_drop.append(y_name)    
            
        




        more_difficult = difficulties[difficulties.index(base_name)+1:]

        for level in more_difficult:
            columns_to_drop.extend([level+'1', level+'2', level+'3'])
            columns_to_drop.extend(['ACC_'+level+'1', 'ACC_'+level+'2', 'ACC_'+level+'3'])
            columns_to_drop.extend(['RT_'+level+'1', 'RT_'+level+'2', 'RT_'+level+'3'])
            #columns_to_drop.append('ACC_'+level)
           # columns_to_drop.append('N_'+level)



        if number_level is not None:
            if number_level == 1:
                columns_to_drop.extend(['ACC_' + base_name+'2','ACC_' +  base_name+'3'])
                columns_to_drop.extend(['RT_' + base_name+'2','RT_' +  base_name+'3'])
                columns_to_drop.extend([base_name+'2', base_name+'3'])
                
                if 'ACC' not in y_name:
                    columns_to_drop.append('ACC_' + base_name + '1')
                    columns_to_drop.append('RT_' + base_name + '1')
                    
                else:
                    columns_to_drop.append(base_name + '1')
                
            elif number_level == 2:
                columns_to_drop.extend(['ACC_' + base_name+'3'])
                columns_to_drop.extend(['RT_' + base_name+'3'])
                columns_to_drop.extend([base_name+'3'])
                
                if 'ACC' not in y_name:
                    columns_to_drop.append('ACC_' + base_name + '2')
                    columns_to_drop.append('RT_' + base_name + '2')
                    
                else:
                    columns_to_drop.append(base_name + '2')
                
            elif number_level == 3:
                if 'ACC' not in y_name:
                    columns_to_drop.append('ACC_' + base_name + '3')
                    columns_to_drop.append('RT_' + base_name + '3')
                    
                else:
                    columns_to_drop.append(base_name + '3')

        
    
    else:
        columns_to_drop = ['n_sum']
        
        
   # print(columns_to_drop)
    return df.drop(columns=columns_to_drop)

# %%
X = make_X(df, 'ADD')

# %%
seed= 0xAB0BA

# %%
np.random.seed(seed)

def get_prediction(X, y, model=None, **kwargs):
    '''
    Works with regression task
    get X - features, y - label, model - model to use. LinReg if None
    
    returns predictions, r2, mse
    '''
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
    
    if model is None:
        model = ElasticNet(**kwargs,
                      tol = 1e-10)
    if model == 'Tree':
        model = DecisionTreeRegressor()
    model.fit(X_train,y_train)
    
    y_pred = model.predict(X_test)
    
    r2 = r2_score(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred, squared = False)
    
    return (y_pred, y_test, r2, rmse)

# %% [markdown]
# $$y = a_1x + a_2x +b$$

# %%
results = {}

for name in tqdm(var_names):
    
    y = globals()[name]
    
    X = make_X(df, name)
    
    y_pred, y_test, r2, mse = get_prediction(X, y, alpha = 3.15, l1_ratio = 0.1, normalize = False, max_iter = 5000)
    
    results[name] = mse
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 100.07it/s]

# %%
results
# Out:
# {'ADD1': 10.718606500213202,
#  'ADD2': 4.287739120094503,
#  'ADD3': 2.880183203671416,
#  'DIV1': 6.61672074602317,
#  'DIV2': 3.7261574867166987,
#  'DIV3': 1.9928173129785198,
#  'MUL1': 8.385594995554541,
#  'MUL2': 2.6955004961438758,
#  'MUL3': 2.2724768060590526,
#  'SUB1': 6.1382024965186375,
#  'SUB2': 3.166941505618094,
#  'SUB3': 1.9829667850928752,
#  'ACC_ADD1': 0.10553090292237144,
#  'ACC_ADD2': 0.17093849736180955,
#  'ACC_ADD3': 0.21766645148978,
#  'ACC_DIV1': 0.16392732539131916,
#  'ACC_DIV2': 0.24868582903700387,
#  'ACC_DIV3': 0.25930428658601984,
#  'ACC_MUL1': 0.13637547567801594,
#  'ACC_MUL2': 0.2259187997982806,
#  'ACC_MUL3': 0.2793155530312851,
#  'ACC_SUB1': 0.13047999610681327,
#  'ACC_SUB2': 0.2536040303431101,
#  'ACC_SUB3': 0.3936419196223931,
#  'ADD': 0.7919610464499945,
#  'DIV': 0.5345228951908686,
#  'MUL': 0.9985468260459264,
#  'SUB': 0.9942351926710972,
#  'SUM': 1.1032709607664255}

# %%
def find_best_utils(X_train, y_train, X_val, y_val, param, **kwargs):
    
    if param == 'alpha':
        param_ls = [0.1, 0.5, 1, 1.5, 2, 3, 3.1, 3.15, 3.2, 3.3, 3.4, 4, 5]
    elif param == 'l1':
        param_ls = [0, 0.001, 0.01, 0.1, 0.5, 1]
    elif param == 'normalize':
        param_ls = [True, False]
    elif param == 'max_iter':
        param_ls = [1000, 2000, 3000, 4000, 5000]
    
    param_dic = {}

    for p in param_ls:

        model = ElasticNet(**kwargs)
        model.fit(X_train,y_train)

        y_pred = model.predict(X_val)

        rmse = mean_squared_error(y_val, y_pred, squared = False)

        param_dic[p] = rmse
        
    best_param = sorted(param_dic.items(), key=lambda item: item[1])[0][0]
    return best_param


def find_best_params(X, y):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.3, random_state = 42)
    
    best_alpha = find_best_utils(X_train, y_train, X_val, y_val, 'alpha')
    
    best_l1 = find_best_utils(X_train, y_train, X_val, y_val, 'l1', alpha=best_alpha)
    
    best_norm = find_best_utils(X_train, y_train, X_val, y_val, 'normalize', alpha=best_alpha, 
                               l1_ratio = best_l1)
    
    best_max_iter = find_best_utils(X_train, y_train, X_val, y_val, 'max_iter', alpha=best_alpha, 
                               l1_ratio = best_l1, normalize = best_norm)
    
    model = ElasticNet(alpha=best_alpha, l1_ratio = best_l1, normalize = best_norm, max_iter = best_max_iter)
    model.fit(X_train,y_train)

    y_pred = model.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred, squared = False)

    
    return (best_alpha, best_l1, best_norm, best_max_iter)

# %%
results1 = {}

for name in tqdm(var_names):
    
    y = globals()[name]
    
    X = make_X(df, name)
    
    a, l1, norm, MI = find_best_params(X, y)
    
    y_pred, y_test, r2, rmse = get_prediction(X, y, alpha = a, l1_ratio = l1, normalize = norm, max_iter = MI)
    
    results1[name] = rmse
# Out:
# 100%|██████████| 29/29 [00:04<00:00,  6.30it/s]

# %%
better = []
for name in results.keys():
    if results[name] > results1[name]:
        better.append((name, results[name] - results1[name]))

# %%
better
# Out:
# [('DIV2', 0.0028724973539033805),
#  ('ACC_ADD1', 0.0004674849281661869),
#  ('ACC_ADD2', 0.0022245997724072153),
#  ('ACC_ADD3', 0.001995262430407152),
#  ('ACC_DIV1', 0.013448235296741995),
#  ('ACC_DIV2', 0.02036310395731844),
#  ('ACC_DIV3', 0.008326717839477416),
#  ('ACC_MUL1', 0.011813717528980486),
#  ('ACC_MUL2', 0.015915673326044544),
#  ('ACC_MUL3', 0.015388103541045917),
#  ('ACC_SUB1', 0.0075045625780715),
#  ('ACC_SUB2', 0.007081234423573529),
#  ('ACC_SUB3', 0.003166567365740114)]

# %%
def Linear_Regression(X,y):
    
    n_columns_not_significant = 1
    while n_columns_not_significant > 0:
        X = sm.add_constant(X)
        mod = sm.OLS(y, X)
        res = mod.fit()
    
        columns_significant = res.pvalues[(res.pvalues < 0.05)].index
        columns_not_significant = res.pvalues[(res.pvalues > 0.05)].index
        n_columns_not_significant = len(columns_not_significant)
        if n_columns_not_significant == 1:
            if columns_not_significant == ['const']:
                break
        
        
        X = X[columns_significant]
    
    return res

# %%
y = globals()['DIV']

X = make_X(df, 'DIV')
res = Linear_Regression(X, y)

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.685
# Method:                 Least Squares   F-statistic:                     96.19
# Date:                Fri, 02 Sep 2022   Prob (F-statistic):           9.05e-53
# Time:                        16:59:51   Log-Likelihood:                -845.24
# No. Observations:                 220   AIC:                             1702.
# Df Residuals:                     214   BIC:                             1723.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0164      4.992      0.003      0.997      -9.824       9.857
# ...

# %%
results = {}

for name in tqdm(var_names):
    y = globals()[name]
    
    res = Linear_Regression(X, y)
    
    r2 = res.rsquared
    params = res.params.index
    
    results[name] = res.summary
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 49.25it/s]

# %%
results['N_ADD1']()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 N_ADD1   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     25.53
# Date:                Tue, 30 Aug 2022   Prob (F-statistic):           2.54e-17
# Time:                        16:46:13   Log-Likelihood:                -841.01
# No. Observations:                 220   AIC:                             1692.
# Df Residuals:                     215   BIC:                             1709.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.2055      7.328      2.484      0.014       3.761      32.650
# ...

# %%
X.columns
# Out:
# Index(['age', 'gender', 'm_score_bal', 'acc_1_bal', 'acc_2_bal', 'acc_3_bal',
#        'acc_4_bal', 'acc_5_bal', 'acc_6_bal', 'rt_1_bal', 'rt_2_bal',
#        'rt_3_bal', 'rt_4_bal', 'rt_5_bal', 'rt_6_bal', 'm_score_cl',
#        'acc_1_cl', 'acc_2_cl', 'acc_3_cl', 'acc_4_cl', 'acc_5_cl', 'acc_6_cl',
#        'rt_1_cl', 'rt_2_cl', 'rt_3_cl', 'rt_4_cl', 'rt_5_cl', 'rt_6_cl',
#        'rt_mean', 'rt_bal', 'rt_cl'],
#       dtype='object')

# %%
for name in tqdm(results):


    plt.rc('figure', figsize=(12, 7))
    #plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 12}) old approach
    plt.text(0.01, 0.05, str(results[name]()), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
    plt.axis('off')
    plt.tight_layout()
    plt.savefig(name+'.jpg')
    plt.show()
# Out:
# ...
# 100%|██████████| 29/29 [00:05<00:00,  5.41it/s]

# %%
plt.rc('figure', figsize=(12, 7))
#plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 12}) old approach
plt.text(0.01, 0.05, str(results[name]()), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
plt.axis('off')
plt.tight_layout()
plt.show()
#plt.savefig('1'+'.jpg')

plt.rc('figure', figsize=(12, 7))
#plt.text(0.01, 0.05, str(model.summary()), {'fontsize': 12}) old approach
plt.text(0.01, 0.05, str(results[name]()), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
plt.axis('off')
plt.tight_layout()

# %%
y = globals()['N_SUM']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
X_train = sm.add_constant(X_train)
mod = sm.OLS(y_train, X_train)

res = mod.fit()

# %%
summary = res.summary()

# %%
summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.452
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     3.528
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):           5.57e-07
# Time:                        18:27:06   Log-Likelihood:                -838.47
# No. Observations:                 154   AIC:                             1737.
# Df Residuals:                     124   BIC:                             1828.
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         207.0878    129.698      1.597      0.113     -49.622     463.797
# ...

# %%
columns_significant = res.pvalues[(res.pvalues < 0.05)].index

# %%
X1 = X_train[columns_significant]
X1 = sm.add_constant(X1)
mod1 = sm.OLS(y_train, X1)

res1 = mod1.fit()
summary1 = res1.summary()

# %%
summary1
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.321
# Method:                 Least Squares   F-statistic:                     25.09
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):           3.25e-13
# Time:                        18:29:06   Log-Likelihood:                -853.48
# No. Observations:                 154   AIC:                             1715.
# Df Residuals:                     150   BIC:                             1727.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        101.5608     38.794      2.618      0.010      24.908     178.214
# ...

# %%
columns_significant = res1.pvalues[(res1.pvalues < 0.05)].index

X1 = X1[columns_significant]
X1 = sm.add_constant(X1)
mod1 = sm.OLS(y_train, X1)

res1 = mod1.fit()
summary1 = res1.summary()

# %%
summary1
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 N_DIV3   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     6.442
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):           0.000393
# Time:                        18:18:05   Log-Likelihood:                -437.56
# No. Observations:                 154   AIC:                             883.1
# Df Residuals:                     150   BIC:                             895.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.6355      3.941      3.967      0.000       7.848      23.423
# ...

# %%
X_train
# Out:
#      const  age  gender  m_score_bal   acc_1_bal   acc_2_bal   acc_3_bal  \
# 163    1.0   12       1            6   89.285714   89.285714   89.285714
# 65     1.0   14       0            7  100.000000   92.857143   96.428571
# 112    1.0   11       1            6   92.857143   96.428571   75.000000
# 186    1.0   12       0            6   96.428571  100.000000   92.857143
# 155    1.0   16       0            6   96.428571  100.000000   92.857143
# ..     ...  ...     ...          ...         ...         ...         ...
# 106    1.0   10       1            5   96.428571  100.000000   75.000000
# 14     1.0   20       0            7   92.857143   96.428571   92.857143
# 92     1.0   16       0            7   96.428571   96.428571  100.000000
# 179    1.0   14       0            7   92.857143   96.428571   96.428571
# 102    1.0   15       1            5   96.428571   96.428571   85.714286
#
#      acc_4_bal  acc_5_bal  acc_6_bal  ...   acc_6_cl   rt_1_cl   rt_2_cl  \
# ...

# %%
X_test = sm.add_constant(X_test)
y_pred = res.predict(X_test)

X_test1 = sm.add_constant(X_test[columns_significant])
y_pred1 = res1.predict(X_test1)

# %%
mean_squared_error(y_test, y_pred, squared = False), mean_squared_error(y_test, y_pred1, squared = False)
# Out:
# (64.16080491525479, 62.8660908951114)

# %%
fig1, ax1 = plt.subplots(figsize=(20, 16))
ax1.hist(np.abs(y_pred-y_test.values), label = 'pred', color='b', bins = 20)
plt.xlabel('log_dist', fontsize=16)
plt.ylabel('density', fontsize=16)
plt.legend()
